# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder

# %%
#load data
data=pd.read_csv(r"final_employee_dataset.csv")
data["salary"].value_counts()
# Out:
# salary
# low       5740
# medium    5261
# high       990
# Name: count, dtype: int64

# %% [markdown]
# # ordinal encoding

# %%
oe=OrdinalEncoder(categories=[["low","medium","high"]])
data["salary"]=oe.fit_transform(data[["salary"]])

# %% [markdown]
# # label encoding

# %%
lb=LabelEncoder()
data["dept"]=lb.fit_transform(data["dept"])

# %%
data
# Out:
#        satisfactory_Level  last_Evaluation  number_Of_Projects  \
# 0                    0.38             0.53                   2
# 1                    0.80             0.86                   5
# 2                    0.11             0.88                   7
# 3                    0.37             0.52                   2
# 4                    0.41             0.50                   2
# ...                   ...              ...                 ...
# 14992                0.30             0.88                   5
# 14995                0.99             0.83                   4
# 14996                0.72             0.72                   4
# 14997                0.24             0.91                   5
# 14998                0.77             0.83                   6
#
#        avg_Monthly_Hours  time_Spent_Company  work_Accident  left  \
# 0                    157                   3              0     1
# 1                    262                   6              0     1
# 2                    272                   4              0     1
# 3                    159                   3              0     1
# 4                    153                   3              0     1
# ...                  ...                 ...            ...   ...
# 14992                245                   4              0     0
# 14995                274                   2              0     0
# 14996                175                   4              0     0
# 14997                177                   5              0     0
# 14998                271                   3              0     0
#
#        promotion_In_Last5years  dept  salary
# 0                            0     7     0.0
# 1                            0     7     1.0
# 2                            0     7     1.0
# 3                            0     7     0.0
# 4                            0     7     0.0
# ...                        ...   ...     ...
# 14992                        0     3     0.0
# 14995                        0     7     0.0
# 14996                        0     9     0.0
# 14997                        0     7     0.0
# 14998                        0     8     0.0
#
# [11991 rows x 10 columns]

# %%
data.to_csv("final_employee_dataset(1).csv")
